# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display
from PIL import ImageFont, ImageDraw, Image

# %%
def createImage(name, fontpath, fontSize):
    blank = np.zeros((100, 500, 3), dtype='uint8')
    blank[:] = 255,255,255
    
    font = ImageFont.truetype(fontpath, fontSize)
    img_pil = Image.fromarray(blank)
    draw = ImageDraw.Draw(img_pil)
    w, h = draw.textsize(name, font = font)
    draw.text(((500-w)/2,(140-h)/2), name, font = font, fill = (0, 0, 0))
    return np.array(img_pil)

# %%
blank = np.zeros((100, 500, 3), dtype='uint8')
blank[:] = 255,255,255

# %%
fontpath = "./fonts/4u-Malith.ttf"     
font = ImageFont.truetype(fontpath, 60)
img_pil = Image.fromarray(blank)
draw = ImageDraw.Draw(img_pil)
w, h = draw.textsize('wxlvf.a', font = font)
draw.text(((500-w)/2,(100-h)/2), "wxlvf.a", font = font, fill = (0, 0, 0))
image = np.array(img_pil)

# %%
import random

def sp_noise(image,prob):
    '''
    Add salt and pepper noise to image
    prob: Probability of the noise
    '''
    output = np.zeros(image.shape,np.uint8)
    thres = 1 - prob 
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            rdn = random.random()
            if rdn < prob:
                output[i][j] = 0
            elif rdn > thres:
                output[i][j] = 255
            else:
                output[i][j] = image[i][j]
    return output

# %%
noisyText = sp_noise(image, 0.05)

# %%
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=500x100 at 0x1B7443EE5E0>

# %%
display(Image.fromarray(noisyText))
# Out:
# <PIL.Image.Image image mode=RGB size=500x100 at 0x1B744466100>

# %%
def gaussianBlur(image, kernalSize, x, y, s):
    blurred_img = cv.GaussianBlur(image, kernalSize, 0)
    mask = np.zeros(image.shape, dtype=np.uint8)
    mask = cv.rectangle(mask, (x, y), (x + 30, y + 30), (255, 255,255), -1)
    out = np.where(mask!=np.array([255, 255, 255]), image, blurred_img)
    return out

# %%
image.shape
# Out:
# (100, 500, 3)

# %%
blurred_img = cv.GaussianBlur(image, (11, 11), 0)

mask = np.zeros((100, 500, 3), dtype=np.uint8)
# mask = cv.circle(mask, (100, 100), 100, (255, 255,255), -1)
mask = cv.rectangle(mask, (250, 50), (280, 80), (255, 255,255), -1)

out = np.where(mask!=np.array([255, 255, 255]), image, blurred_img)

# %%
s = 30
x,  y = random.randint((image.shape[1] - w)//2, (image.shape[1] + w)//2 - s), random.randint((image.shape[0] - h)//2, (image.shape[0] + h)//2 - s)
out = gaussianBlur(image, (11, 11), x, y, s)

# %%
display(Image.fromarray(out))
# Out:
# <PIL.Image.Image image mode=RGB size=500x100 at 0x1B7444666A0>

# %%
from os import path

path.abspath('')
# Out:
# 'c:\\Users\\Yasith\\Documents\\GitHub\\FYP-Omega\\Error data\\OCR Error Data'

# %%
#file_path = (base_path / "../Data/legacy - train.txt").resolve()
import pytesseract
import regex as re
import pandas as pd

x=35 

fonts = ['fonts/4u-Malith.ttf','fonts/FM_Abhaya.ttf']
col = ['Malith','Abhaya']
for n in range(x,36):
    #uni = open('c:\\Users\\Yasith\\Documents\\GitHub\\FYP-Omega\\Data/combined all names - cleaned - train.txt', 'r', encoding='utf-8').readlines()[(n-1)*25000:n*25000]
    uni = open('c:\\Users\\Yasith\\Documents\\GitHub\\FYP-Omega\\Data/combined all names - cleaned - train.txt', 'r', encoding='utf-8').readlines()[850000:]
    error = pd.DataFrame()
    error['original']=uni
    error['original'] = error['original'].str.replace(r'\n', '')

    #names = open('c:\\Users\\Yasith\\Documents\\GitHub\\FYP-Omega\\Data/legacy - train.txt', 'r', encoding='utf-8').readlines()[(n-1)*25000:n*25000]
    names = open('c:\\Users\\Yasith\\Documents\\GitHub\\FYP-Omega\\Data/legacy - train.txt', 'r', encoding='utf-8').readlines()[850000:]
    num=0
    for i in range(2):
        ocr=[]
        for line in names:
            #unicodeName, legacyName = line.strip().split('\t')
            image = createImage(line, fonts[i], 60)
            noisyImage = sp_noise(image, 0.05)
            s = 30
            x,  y = random.randint((image.shape[1] - w)//2, (image.shape[1] + w)//2 - s), random.randint((image.shape[0] - h)//2, (image.shape[0] + h)//2 - s)
            bluredImage = gaussianBlur(noisyImage, (11, 11), x, y, s)
            #display(Image.fromarray(bluredImage))
            # cv.imwrite(f'Train/{num}.jpg', bluredImage)

            text = pytesseract.image_to_string(bluredImage, lang='sin',config='--psm 8')
            text = re.sub(r'[^\w]|_|[a-zA-Z]|[0-9]|\u200c', '', text)
            text = text.strip()
            #print(uni[num],text)
            ocr.append(text)
            #print()
            # unic=uni[num].strip()
            # if not (unic==text):
            #     count+=1
            #     print(uni[num].strip(),text)
            num+=1
            if num%5000==0:
                print (num)
        error[col[i]] = ocr
    error.head()
    error.to_csv(f'OCR errors training - {n}.csv',encoding='utf-8-sig',index=False)
# Out:
# C:\Users\Yasith\AppData\Local\Temp/ipykernel_21760/3591983719.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   error['original'] = error['original'].str.replace(r'\n', '')
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# 35000
# 40000
# 45000
# 50000
# 55000

# %%
uni = open('c:\\Users\\Yasith\\Documents\\GitHub\\FYP-Omega\\Data/combined all names - cleaned - train.txt', 'r', encoding='utf-8').readlines()
len(uni)
# Out:
# 878599
